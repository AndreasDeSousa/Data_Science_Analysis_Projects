# %% [markdown]
# <h1 style="color:Orange;font-size:170%;">Correlation between movies variables in Python </h>

# %% [markdown]
# ## Import
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Import the data and start to investigate

# %%
# Now we need to read in the data
df = pd.read_csv(r'Datasets\movies.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Check for missing data (null values)

null_columns = df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# rating        77
# released       2
# score          3
# votes          3
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# We can see that we have some null value on the frame

df[df.isnull().any(axis=1)][null_columns]
# Out:
#      rating                           released  score    votes  \
# 16        R       May 16, 1980 (United States)    6.6  21000.0
# 19        R  December 12, 1980 (United States)    6.8  26000.0
# 24       PG       June 6, 1980 (United States)    6.4  14000.0
# 25        R  December 25, 1980 (United States)    6.9  33000.0
# 26        R     March 21, 1980 (United States)    6.5   5100.0
# ...     ...                                ...    ...      ...
# 7663    NaN   October 23, 2020 (United States)    3.1     18.0
# 7664    NaN   February 7, 2020 (United States)    4.7     36.0
# 7665    NaN          April 27, 2020 (Cameroon)    5.7     29.0
# 7666    NaN    October 1, 2020 (United States)    NaN      NaN
# 7667    NaN    August 19, 2020 (United States)    5.7      7.0
#
#                   writer              star        country   budget  \
# 16      Christopher Gore       Eddie Barth  United States      NaN
# 19    Bruce Jay Friedman       Gene Wilder  United States      NaN
# ...

# %%
df.fillna(0, inplace=True)
df.head(17)
# Out:
#                                               name rating      genre  year  \
# 0                                      The Shining      R      Drama  1980
# 1                                  The Blue Lagoon      R  Adventure  1980
# 2   Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                        Airplane!     PG     Comedy  1980
# 4                                       Caddyshack      R     Comedy  1980
# 5                                  Friday the 13th      R     Horror  1980
# 6                               The Blues Brothers      R     Action  1980
# 7                                      Raging Bull      R  Biography  1980
# 8                                      Superman II     PG     Action  1980
# 9                                  The Long Riders      R  Biography  1980
# 10                           Any Which Way You Can     PG     Action  1980
# ...

# %%
null_columns = df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df["budget"] = df["budget"].astype("int64")
df["gross"] = df["gross"].astype("int64")

# %%
df["budget"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Correct the year column

# %%
df[["released", "year"]]
# Out:
#                               released  year
# 0        June 13, 1980 (United States)  1980
# 1         July 2, 1980 (United States)  1980
# 2        June 20, 1980 (United States)  1980
# 3         July 2, 1980 (United States)  1980
# 4        July 25, 1980 (United States)  1980
# ...                                ...   ...
# 7663  October 23, 2020 (United States)  2020
# 7664  February 7, 2020 (United States)  2020
# 7665         April 27, 2020 (Cameroon)  2020
# 7666   October 1, 2020 (United States)  2020
# 7667   August 19, 2020 (United States)  2020
#
# [7668 rows x 2 columns]

# %%
df["rel_year"] = df["released"].str.split(' \(').str[0]
df["rel_year"] = df["rel_year"].str[-4:]
df.fillna(0, inplace=True)
df["rel_year"]= pd.to_numeric(df["rel_year"])
df["Same_year_checker"] = np.where(df["rel_year"] == df["year"], True, False)
df_year_mismatch = df.loc[df['Same_year_checker'] == False]
df_year_mismatch[["released", "rel_year","year"]]
# Out:
#                               released  rel_year  year
# 8        June 19, 1981 (United States)      1981  1980
# 11    October 26, 1984 (United States)      1984  1980
# 21      April 24, 1981 (United States)      1981  1980
# 33      April 24, 1981 (United States)      1981  1980
# 40     October 9, 1981 (United States)      1981  1980
# ...                                ...       ...   ...
# 7525  January 17, 2020 (United States)      2020  2019
# 7580     June 26, 2020 (United States)      2020  2019
# 7584      February 4, 2020 (Australia)      2020  2019
# 7604             May 19, 2020 (Poland)      2020  2019
# 7641     March 3, 2020 (United States)      2020  2019
#
# [1326 rows x 3 columns]

# %%
df["year"] = df["rel_year"]
df.drop(columns=['rel_year','Same_year_checker'], axis ='columns', inplace=True)
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
df.sort_values(by='gross', inplace=False,ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1990
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1990
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# option to see all the row of a dataframe
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Drop duplicates values

# %%
# Shows all the unique values of companies
# in this case drop_duplicates show us what values are distinct. for actually drop this values ve need to reassign the values to the column df['company'] = df['company']....
df['company'].astype("str").drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 6412               iDeal Partners Film Fund
# 4007                               i5 Films
# 6793                             i am OTHER
#                        ...
# 3748                     1+2 Seisaku Iinkai
# 408                                       0
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 2386, dtype: object

# %% [markdown]
# There are no duplicates on company column. In case there was was necessary to clean and correct tht data.

# %% [markdown]
# ## Finding correlation between data
# ### Scatter plot budget vs gross

# %%
plt.scatter(x=df["budget"],y=df["gross"])
plt.title("Correlation Budget vs Gross Earnings")
plt.xlabel("Budget for film")
plt.ylabel("Gross Earning")
plt.show()

# %%
df.sort_values(by='gross', inplace=False,ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1990
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1990
# 7667                                   Tee em el      0   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %% [markdown]
# ### Plotting budget vs gross using seaborn

# %%
sns.regplot(x='budget',y='gross',data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %% [markdown]
# ### Let's start to looking to correlation
#  There are different methods for correlation:
#  * pearson (default)
#  * kendall
#  * spearman
# Check when to use which type.

# %%
df.corr(method = 'kendall') #  is only work on numerical data
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.072838  0.324315  0.200629  0.206940  0.097006
# score    0.072838  1.000000  0.300673 -0.004843  0.091331  0.283601
# votes    0.324315  0.300673  1.000000  0.439883  0.560449  0.197697
# budget   0.200629 -0.004843  0.439883  1.000000  0.541956  0.176184
# gross    0.206940  0.091331  0.560449  0.541956  1.000000  0.177429
# runtime  0.097006  0.283601  0.197697  0.176184  0.177429  1.000000

# %% [markdown]
# There si a high correlation between budget and gross

# %%
corr_matrix = df.corr(method='pearson')
sns.heatmap(corr_matrix, annot = True)
plt.title("Correlation Matrix for numeric features")
plt.xlabel("Movie feature")
plt.ylabel("Movie feature")
plt.show()

# %% [markdown]
# ### Looking at full correlation with companies

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1981
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %% [raw]
# As we can see companies doesn't have numerical values. for check their correlation we can enumerate the companies so they will have a unique identifier and can be included on the correlation matrix

# %%
df_num = df.copy()

for col_name in df_num.columns:
    if df_num[col_name].dtype == 'object':
        df_num[col_name] = df_num[col_name].astype('category')
        df_num[col_name] = df_num[col_name].cat.codes

# %% [markdown]
# Let compare the 2 dataframe to see if everything works properly

# %%
df_num
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       7      6  1980      1706    8.4   927000.0      2589    4015
# 1     5573       7      1  1980      1493    5.8    65000.0      2269    1633
# 2     5142       5      0  1980      1772    8.7  1200000.0      1111    2568
# 3      286       5      4  1980      1493    7.7   221000.0      1301    2001
# 4     1027       7      4  1980      1544    7.3   108000.0      1054     522
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705       0      6  2020      2965    3.1       18.0      1500    2290
# 7664  1678       0      4  2020      1108    4.7       36.0       774    2615
# 7665  4717       0      6  2020       194    5.7       29.0      2061    2684
# 7666  2843       0      6  2020      2818    0.0        0.0      1184    1825
# 7667  5394       0     10  2020       392    5.7        7.0      2165    3345
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life      0      Drama  2020
# 7664                                     Dream Round      0     Comedy  2020
# 7665                                   Saving Mbango      0      Drama  2020
# 7666                                    It's Just Us      0      Drama  2020
# 7667                                       Tee em el      0     Horror  2020
#
# ...

# %%
corr_matrix_num = df_num.corr(method='pearson')
sns.heatmap(corr_matrix_num, annot = True)
plt.title("Correlation Matrix for all features")
plt.xlabel("Movie feature")
plt.ylabel("Movie feature")
plt.show()

# %%
corr_matrix_num
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355 -0.010642 -0.011311  0.016377
# rating   -0.008069  1.000000  0.072423 -0.007922  0.016613  0.006192
# genre     0.016355  0.072423  1.000000 -0.035768  0.029822  0.027384
# year     -0.010642 -0.007922 -0.035768  1.000000  0.024619  0.043598
# released -0.011311  0.016613  0.029822  0.024619  1.000000  0.039814
# score     0.016377  0.006192  0.027384  0.043598  0.039814  1.000000
# votes     0.013038  0.033743 -0.145296  0.070183  0.015878  0.407101
# director  0.009079  0.019483 -0.015258 -0.005853 -0.001478  0.010568
# writer    0.009081 -0.005921  0.006567  0.003654 -0.002404  0.022098
# star      0.006472  0.013405 -0.005477 -0.009503  0.015777 -0.000026
# country  -0.010737  0.081244 -0.037615  0.024378 -0.020427 -0.133346
# budget    0.020548 -0.081939 -0.334021  0.108069  0.009145  0.056863
# gross     0.006989 -0.095450 -0.234297  0.090394  0.000519  0.186012
# ...

# %%
corr_pairs = corr_matrix_num.unstack()
corr_pairs
# Out:
# name     name        1.000000
#          rating     -0.008069
#          genre       0.016355
#          year       -0.010642
#          released   -0.011311
#                        ...
# runtime  country    -0.073319
#          budget      0.268372
#          gross       0.244339
#          company     0.037537
#          runtime     1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(ascending= False)
sorted_pairs
# Out:
# name     name       1.000000
# rating   rating     1.000000
# company  company    1.000000
# gross    gross      1.000000
# budget   budget     1.000000
#                       ...
# genre    votes     -0.145296
#          gross     -0.234297
# gross    genre     -0.234297
# budget   genre     -0.334021
# genre    budget    -0.334021
# Length: 225, dtype: float64

# %% [markdown]
# Let's check for the higher correlation between variables

# %%
high_corr = sorted_pairs[(sorted_pairs > 0.5) & (sorted_pairs != 1.0)]
high_corr
# Out:
# gross   budget    0.750157
# budget  gross     0.750157
# votes   gross     0.632870
# gross   votes     0.632870
# dtype: float64

# %% [markdown]
# ## Conclusion
#
# After this project we could learn some technique for data cleaning and correlation. A swe saw the highest correlation between variables results to be between gross vs budget and gross vs votes.
